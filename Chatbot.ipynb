# %% [markdown]
# <a href="https://colab.research.google.com/github/Arnab0610/Arnab0610/blob/main/Chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = input("Enter your name:")
print("Hello",name)

for i in range (10000):
  chat=str(input("ask some question...:"))
  if chat=="what is your name":
      print("My name is alex")
  elif chat=="Who made you":
      print("arnab made me")
  elif chat=="What is your favorit food":
      print("your data")
